# %% [markdown]
# # Asg-4 focuses on
#
# ## NFA2DFA (review) -- LT
#
# ## Reversal of NFA by hand -- XL
#
# ## Conversion to GNFA and Two Elimination Orders -- AR
#
# ## Chasing down the RE2NFA Components -- SV
#
# ## Here is the  plan
#
# 1. In LT, you will
#
#     a. take a given nfa called nfa1
#
#     b. convert it to dfa1
#
#     c. reverse nfa1 by hand obtaining rnfa1
#
#     d. inspect and conclude (listing six paths) that rnfa1 is indeed a reverse of nfa1
#
# 2. In XL you will
#
#     a. learn about a few DFA utilities such as totalize_dfa and dotObj_dfa_w_bh
#
#     b. extract an RE by inspecting nfa1 and write it down as RE1_hand
#
#     c. reverse RE1_hand by inspection, writing the result down as Rev_RE1_hand
#
#     d. Understand the function del_gnfa_states via its help command
#
#
# 3. In AR you will
#
#     a. obtain a GNFA for rnfa1, calling it grnfa1
#
#     b. apply two elimination orders for states on grnfa1
#
#     c. obtain Rev_RE1 and Rev_RE2
#
#     d. check that Rev_RE1 and Rev_RE2 and Rev_RE1_hand are all isomorphic
#
#
# 4. In SV you will
#
#     a. print the NFA for Rev_RE2 and answer the stated questions.
#
#     b. print the NFA for Rev_RE1_hand and answer the questions.
#
# Please follow the instructions and submit your finished notebook as described in previous assignments.

# %% [markdown]
# # Asg-4 imports

# %%
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
import sys

# -- Detect if in Own Install or in Colab
try:
    import google.colab
    OWN_INSTALL = False
except:
    OWN_INSTALL = True
    
if OWN_INSTALL:
    
  #---- Leave these definitions ON if running on laptop
  #---- Else turn OFF by putting them between ''' ... '''

  sys.path[0:0] = ['../../../../..',  '../../../../../3rdparty',  
                   '../../../..',  '../../../../3rdparty',  
                   '../../..',     '../../../3rdparty', 
                   '../..',        '../../3rdparty',
                   '..',           '../3rdparty' ]

else: # In colab
  ! if [ ! -d Jove ]; then git clone https://github.com/ganeshutah/Jove Jove; fi
  sys.path.append('./Jove')
  sys.path.append('./Jove/jove')

# -- common imports --
from jove.DotBashers import *
from jove.Def_md2mc  import *
from jove.Def_NFA    import *
from jove.Def_DFA    import *
from jove.Def_NFA2RE import *
from jove.Def_RE2NFA import *
from jove.AnimateNFA import *
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Out:
# You may use any of these help commands:
# help(ResetStNum)
# help(NxtStateStr)
#
# You may use any of these help commands:
# help(md2mc)
# .. and if you want to dig more, then ..
# help(default_line_attr)
# help(length_ok_input_items)
# help(union_line_attr_list_fld)
# help(extend_rsltdict)
# help(form_delta)
# help(get_machine_components)
#
# You may use any of these help commands:
# help(mkp_dfa)
# help(mk_dfa)
# help(totalize_dfa)
# help(addtosigma_delta)
# help(step_dfa)
# help(run_dfa)
# help(accepts_dfa)
# help(comp_dfa)
# help(union_dfa)
# help(intersect_dfa)
# help(pruneUnreach)
# help(iso_dfa)
# help(langeq_dfa)
# help(same_status)
# help(h_langeq_dfa)
# help(fixptDist)
# help(min_dfa)
# help(pairFR)
# help(state_combos)
# help(sepFinNonFin)
# help(bash_eql_classes)
# help(listminus)
# help(bash_1)
# help(mk_rep_eqc)
# help(F_of)
# help(rep_of_s)
# help(q0_of)
# help(Delta_of)
# help(mk_state_eqc_name)
#
# You may use any of these help commands:
# help(mk_nfa)
# help(totalize_nfa)
# help(step_nfa)
# help(run_nfa)
# help(ec_step_nfa)
# help(Eclosure)
# help(Echelp)
# help(accepts_nfa)
# help(nfa2dfa)
# help(n2d)
# help(inSets)
# help(rev_dfa)
# help(min_dfa_brz)
#
# You may use any of these help commands:
# help(RE2Str)
# help(mk_gnfa)
# help(mk_gnfa_from_D)
# help(dfa2nfa)
# help(del_gnfa_states)
# help(gnfa_w_REStr)
# help(del_one_gnfa_state)
# help(Edges_Exist_Via)
# help(choose_state_to_del)
# help(form_alt_RE)
# help(form_concat_RE)
# help(form_kleene_RE)
#
# You may use any of these help commands:
# help(re2nfa)

# %% [markdown]
# # 1. NFA to DFA by hand and Checking (LT) + Getting a simple RE
#
# You are given this NFA below
#
# ## 1(a). nfa1 is given below
#
# Questions follow under 1(b)

# %%
# Given NFA

nfa1 = md2mc('''NFA
I1 : '' -> B
I1 : a  -> I2

I2 : c  -> F3
I2 : b  -> B

B : s  -> B
B : d  -> F4
B : f  -> F3


''')
# Out:
# Generating LALR tables

# %%
dotObj_nfa(nfa1)

# %% [markdown]
# ## 1(b). Obtain the DFA of the above NFA by hand. I've given you a start.
#
# 1. Obtain the Eclosure of the initial NFA state. That is the DFA's initial state.
#
# 2. When we go from I1_I2_B (set of states corresponding to the Eclosure) and give that state 'a', it goes to "wasI2". This is no longer the initial state of the DFA, and hence called "wasI2".
#
# 3. Finish the remaining steps below.
#
# Show your work by typing in the Eclosure details of each step wherever there is a $\varepsilon$ involved in a given DFA state
#
# For DFA states where there is no $\varepsilon$ involved, just show the final Eclosed result.
#
# Use as many bullets as necessary to clearly show your work:
#
# * Going from `I1_I2_B`:
#   - Obtain the E-closure of `{I1, I2, B}`, yielding `{I1, I2, B}`.
#   - When we go from `I1_I2_B` (set of states corresponding to the E-closure) and give that state either a **'b'** or an **'s'**, it goes to `{B}`, whose E-closure is `{B}`, which didn't add any new states.
#   - Call that destination state `B`.
#
# * Going from `I1_I2_B`:
#   - Obtain the E-closure of `{I1, I2, B}`, yielding `{I1, I2, B}`.
#   - When we go from `I1_I2_B` (set of states corresponding to the E-closure) and give that state a **'d'**, it goes to `{F4}`, whose E-closure is `{F4}`, which didn't add any new states.
#   - Call that destination state `F4`. Since it was a final state in the original NFA, it will also be a final state in the DFA.
#
# * Going from `I1_I2_B`:
#   - Obtain the E-closure of `{I1, I2, B}`, yielding `{I1, I2, B}`.
#   - When we go from `I1_I2_B` (set of states corresponding to the E-closure) and give that state a **'c'** or an **'f'**, it goes to `{F3}`, whose E-closure is `{F3}`, which didn't add any new states.
#   - Call that destination state `F3`. Since it was a final state in the original NFA, it will also be a final state in the DFA.
#
# * Going from `wasI2`:
#   - Obtain the E-closure of `{I2}`, yielding `{I2}`.
#   - When we go from `wasI2` (set of states corresponding to the E-closure) and give that state a **'b'**, it goes to `{B}`, whose E-closure is `{B}`, which didn't add any new states.
#   - Call that destination state `B`, which already exists.
#
# * Going from `wasI2`:
#   - Obtain the E-closure of `{I2}`, yielding `{I2}`.
#   - When we go from `wasI2` (set of states corresponding to the E-closure) and give that state a **'c'**, it goes to `{F3}`, whose E-closure is `{F3}`, which didn't add any new states.
#   - Call that destination state `F3`, which already exists.
#
# * Going from `B`:
#   - Obtain the E-closure of `{B}`, yielding `{B}`.
#   - When we go from `B` (set of states corresponding to the E-closure) and give that state a **'d'**, it goes to `{F4}`, whose E-closure is `{F4}`, which didn't add any new states.
#   - Call that destination state `F4`, which already exists.
#
# * Going from `B`:
#   - Obtain the E-closure of `{B}`, yielding `{B}`.
#   - When we go from `B` (set of states corresponding to the E-closure) and give that state a **'f'**, it goes to `{F3}`, whose E-closure is `{F3}`, which didn't add any new states.
#   - Call that destination state `F3`, which already exists.
#
# * Going from `B`:
#   - Obtain the E-closure of `{B}`, yielding `{B}`.
#   - When we go from `B` (set of states corresponding to the E-closure) and give that state a **'s'**, it goes to `{B}`, whose E-closure is `{B}`, which didn't add any new states.
#   - Call that destination state `B`, which already exists.

# %%
# DFA of nfa1

dfa1 = md2mc('''DFA

I1_I2_B :a-> wasI2
I1_I2_B :b|s-> B
I1_I2_B :c|f-> F3
I1_I2_B :d-> F4

wasI2 :b-> B
wasI2 :c-> F3

B :d-> F4
B :f-> F3
B :s-> B

''')
# Out:
# Generating LALR tables

# %%
dotObj_dfa(dfa1)

# %% [markdown]
# ## 1(c). Reverse nfa1 by hand, below. In doing so, it is helpful for me to suggest state renamings for you
#
# 1) Change F3 to I3
#
# 2) Change F4 to I4
#
# 3) Change I1 and I2 to F1 and F2
#
# 4) Now, reverse the transitions of nfa1, obtaining "rnfa1" below

# %%
# There is no Jove function to reverse automatically - do it by hand!

rnfa1 = md2mc('''
NFA

I4 :d-> B

I3 :c-> F2
I3 :f-> B

B :''-> F1
B :b-> F2
B :s -> B

F2 :a-> F1

''')
# Out:
# Generating LALR tables

# %%
dotObj_nfa(rnfa1)

# %%
dotObj_nfa(nfa1)

# %% [markdown]
# ## 1(d). Inspect and conclude that rnfa1 is truly the reverse of nfa1
#
#
# ### List the first six strings in numeric order and check that they have been correctly reversed.
#
# State the string in the original machine and explain (by specifying a path as a sequence of states) that this string is present in the reversed machine also.
#
# 1. "c", reversed: "c"
#   * In the original NFA: `I2 :c-> F3`
#   * In the reversed NFA: `I3 :c-> F2`
#
# 2. "d", reversed: "d"
#   - In the original NFA: `I1 :''-> B :d-> F4`
#   - In the reversed NFA: `I4 :d-> B :''-> F1`
#
# 3. "f", reversed: "f"
#   - In the original NFA: `I1 :''-> B :f-> F3`
#   - In the reversed NFA: `I3 :f-> B :''-> F1`
#
# 4. "ac", reversed: "ca"
#   - In the original NFA: `I1 :a-> I2 :c-> F3`
#   - In the reversed NFA: `I3 :c-> F2 :c-> F1`
#
# 5. "bd", reversed: "db"
#   - In the original NFA: `I2 :b-> B :d-> F4`
#   - In the reversed NFA: `I4 :d-> B :b-> F2`
#
# 6. "bf", reversed: "fb"
#   - In the original NFA: `I2 :b-> B :f-> F3`
#   - In the reversed NFA: `I3 :f-> B :b-> F2`

# %% [markdown]
# # 2. Extraction of RE by Inspection (XL) and other things before it

# %% [markdown]
# ## 2(a). You can totalize dfa1 to obtain the totalized machine
#
# * Explain totalize_dfa in a few sentences below, by looking at the Delta before and After

# %%
tdfa1 = totalize_dfa(dfa1)
print("dfa1:", dfa1, "\n")
print("tdfa1:", tdfa1)
# Out:
# dfa1: {'Q': {'B', 'I1_I2_B', 'F3', 'F4', 'wasI2'}, 'Sigma': {'a', 'd', 'c', 'b', 'f', 's'}, 'Delta': {('I1_I2_B', 'a'): 'wasI2', ('I1_I2_B', 'b'): 'B', ('I1_I2_B', 's'): 'B', ('I1_I2_B', 'c'): 'F3', ('I1_I2_B', 'f'): 'F3', ('I1_I2_B', 'd'): 'F4', ('wasI2', 'b'): 'B', ('wasI2', 'c'): 'F3', ('B', 'd'): 'F4', ('B', 'f'): 'F3', ('B', 's'): 'B'}, 'q0': 'I1_I2_B', 'F': {'F3', 'F4'}}
#
# tdfa1: {'Q': {'B', 'I1_I2_B', 'BH', 'F3', 'F4', 'wasI2'}, 'Sigma': {'a', 'd', 'c', 'b', 'f', 's'}, 'Delta': {('I1_I2_B', 'a'): 'wasI2', ('I1_I2_B', 'b'): 'B', ('I1_I2_B', 's'): 'B', ('I1_I2_B', 'c'): 'F3', ('I1_I2_B', 'f'): 'F3', ('I1_I2_B', 'd'): 'F4', ('wasI2', 'b'): 'B', ('wasI2', 'c'): 'F3', ('B', 'd'): 'F4', ('B', 'f'): 'F3', ('B', 's'): 'B', ('B', 'a'): 'BH', ('B', 'c'): 'BH', ('B', 'b'): 'BH', ('F3', 'a'): 'BH', ('F3', 'd'): 'BH', ('F3', 'c'): 'BH', ('F3', 'b'): 'BH', ('F3', 'f'): 'BH', ('F3', 's'): 'BH', ('F4', 'a'): 'BH', ('F4', 'd'): 'BH', ('F4', 'c'): 'BH', ('F4', 'b'): 'BH', ('F4', 'f'): 'BH', ('F4', 's'): 'BH', ('wasI2', 'a'): 'BH', ('wasI2', 'd'): 'BH', ('wasI2', 'f'): 'BH', ('wasI2', 's'): 'BH', ('BH', 'a'): 'BH', ('BH', 'd'): 'BH', ('BH', 'c'): 'BH', ('BH', 'b'): 'BH', ('BH', 'f'): 'BH', ('BH', 's'): 'BH'}, 'q0': 'I1_I2_B', 'F': {'F3', 'F4'}}

# %% [markdown]
# ### Your explanation of totalize_dfa
#
# * `totalize_dfa` checked every state in the original DFA if they assigned a path upon every symbol in the alphabet. It then created paths from every state to a "black-hole" state (named `BH`) upon getting any of those missing symbols.
#
# * A black-hole state is simply a non-final state that wraps any input to itself, making it unescapable. Once entered this state, the machine will never accept the string no matter how long the input is.

# %% [markdown]
# ##  A printout may look the same ... till you print w_bh

# %%
dotObj_dfa(tdfa1)

# %% [markdown]
# ##  Let us print with blackhole

# %%
dotObj_dfa_w_bh(tdfa1)

# %% [markdown]
# ### Was it a good idea to not always show black-holes?
#
# * In what circumstances might you still need to apply the _w_bh view option?
#
# I think it is a good idea to hide the black-holes in most cases, because it makes the graph much more easier to read; the readers would just agree that any undefined input always leads to the black-hole.
#
# However, a DFA should have a path for every possible input from any state since that was one of the requirements. In the case someone wanted to view the *complete* version of any DFA, black-holes should be shown.

# %% [markdown]
# ## 2(b) Obtain an RE by looking at nfa1
#
# * Follow all paths
#
# * Summarize the paths in your head, using the Star operator suitably

# %%
dotObj_nfa(nfa1)

# %%
RE1_hand = "(''+a)c+(''+b+ab)s*(d+f)"

# %% [markdown]
# ## 2(c) Reverse RE1 by hand to obtain Rev_RE1
#
# Once you have an RE, you can "visually reverse it" for simple REs

# %%
Rev_RE1_hand = "c(''+a)+(d+f)s*(''+b+ba)"

# %% [markdown]
# ## 2(d) Understand del_gnfa_states via help

# %%
# help of del_gnfa_states run below
help(del_gnfa_states)
# Out:
# Help on function del_gnfa_states in module jove.Def_NFA2RE:
#
# del_gnfa_states(Gin, DelList=[])
#     Given a GNFA Gin with no unreachable states,
#     delete all states but f
#     or Real_I and Real_F.
#     If DelList is given, follow the state deletion
#     order mentioned therein; else choose order internally.
#
#     Return a triple (Gfinal, dotObj_List, final_re_str), where
#       Gfinal       : the final GNFA
#       dotObj_List  : a list of Dot objects recording the process of
#                      deleting states and forming intermediate REs
#       final_re_str : the final RE as a string (ready to be fed to
#                      re2nfa for converting back to an NFA)

# %% [markdown]
# ### Document what you learned from the function help of del_gnfa_states and summarize below
#
#
# * The function `del_gnfa_states` takes two arguments: a generalized NFA with no unreachable states, and optionally, the order of which the states should be eliminated one by one.
#
# * The function will then elimiante the states between the initial and final states in the NFA in the provided order (or an arbitrary order if none was set). By eliminating the states it generates/combines the symbols on the paths into intermediate regular expressions, and finally into one comprehensive RE described by the NFA.
#
# * The function then returns the resulting NFA and the regular expression generated. It even records the elimination process so we can use that result to better study how a regular expression is read from an NFA.

# %% [markdown]
# # 3. Converting to GNFA and Attempting Two Elimination Orders (AR)
#
# Work on rnfa1 to obtain Rev_RE1 and Rev_RE2

# %% [markdown]
# ## Obtain grnfa1 below via a suitable command

# %%
grnfa1 = mk_gnfa(rnfa1)

# %%
dotObj_gnfa(grnfa1)

# %% [markdown]
# ## 3(b,c) i : Apply the elimination order by supplying the second argument
# ['B', 'F2', 'F1', 'I3', 'I4']
#
# as you learned in the help

# %%
grnfa1_del_order = ['B', 'F2', 'F1', 'I3', 'I4']
(Gfinal, DO, Rev_RE1) = del_gnfa_states(grnfa1, grnfa1_del_order)
# Out:
# **** Eliminating state B ****
# **** Eliminating state F2 ****
# **** Eliminating state F1 ****
# **** Eliminating state I3 ****
# **** Eliminating state I4 ****

# %%
Rev_RE1
# Out:
# '((((((((d ((s)* b)) a) + (d (s)*)) + (d (s)*)) + (d ((s)* b))) + (d ((s)* b))) + ((((((((f ((s)* b)) + c) + c) a) + (f (s)*)) + (f (s)*)) + (((f ((s)* b)) + c) + c)) + (((f ((s)* b)) + c) + c))) + ((((((((f ((s)* b)) + c) + c) a) + (f (s)*)) + (f (s)*)) + (((f ((s)* b)) + c) + c)) + (((f ((s)* b)) + c) + c)))'

# %%
dotObj_dfa(min_dfa(nfa2dfa(re2nfa(Rev_RE1))))

# %%
DO[0]

# %%
DO[1]

# %% [markdown]
# ## Examine DO[0] through DO[Last_Legal_Item] (find out how long DO is)
#
# DO[0] is the initial GNFA machine, DO[1] is the next one, and so on. You will see each step getting
# rid of one state.
#
# ### [[ ...UPDATED WORDING...]] Summarize your observation of the state elimination and which REs were introduced as a result. Pick TWO cases, one of which involves the removal of a state with a self-loop. Use one bullet per question case discussed.
#
# <!--
# **** Eliminating state B ****
# **** Eliminating state F2 ****
# **** Eliminating state F1 ****
# **** Eliminating state I3 ****
# **** Eliminating state I4 ****
# -->
#
# * Going from `DO[0]` to `DO[1]`, the state `B` got eliminated. Since there was a self-loop on state `B` upon the symbol 's', when connecting the REs coming in and going out of `B`, "s\*" was added in between. The input REs were "d" from state `I4` and "f" from state `I3`, and the outputs were "" to state `F1` and "b" to state `F2`. Thus, the elimation of `B` introduced four new paths: `I4` goes to `F2` upon "bs\*", `I4` goes to to `F1` upon "ds\*b", `I3` goes to `F2` upon "fs\*", and `I3` goes to to `F1` upon "fs\*b". Finally, since there already existed a path from `I3` to `F1` upon "c", this path and the newly created path combined to form a path going upon "(fs\*b)+c".
#
# * Going from `DO[3]` to `DO[4]`, the state `I4` got eliminated. The input RE was "" from state `Real_I`, and the outputs were "(((((((f ((s)\* b)) + c) + c) a) + (f (s)\*)) + (f (s)\*)) + (((f ((s)\* b)) + c) + c))" and "(((f ((s)\* b)) + c) + c)", both head toward `Real_F`. Thus, the elimation of `I4` introduced two new paths: `Real_I` goes to `Real_F` upon "(((((((f ((s)\* b)) + c) + c) a) + (f (s)\*)) + (f (s)\*)) + (((f ((s)\* b)) + c) + c))" and upon "(((f ((s)\* b)) + c) + c)". Finally, these two paths combined to form a path going upon "((((((((f ((s)\* b)) + c) + c) a) + (f (s)\*)) + (f (s)\*)) + (((f ((s)\* b)) + c) + c)) + (((f ((s)\* b)) + c) + c))".

# %% [markdown]
# ## 3(b,c) ii : Apply the elimination order by supplying the second argument
#  ['I3', 'I4', 'F1', 'B', 'F2' ]
#
# as you learned in the help

# %%
grnfa1_del_order2 = ['I3', 'I4', 'F1', 'B', 'F2' ]
(Gfinal, DO, Rev_RE2) = del_gnfa_states(grnfa1, grnfa1_del_order2)
# Out:
# **** Eliminating state I3 ****
# **** Eliminating state I4 ****
# **** Eliminating state F1 ****
# **** Eliminating state B ****
# **** Eliminating state F2 ****

# %%
Rev_RE2
# Out:
# '((((((((d + f) + f) ((s)* b)) + c) + c) ((a + "") + "")) + (((d + f) + f) (s)*)) + (((d + f) + f) (s)*))'

# %%
DO[3]

# %%
DO[4]

# %% [markdown]
# ## Examine DO[0] through DO[Last_Legal_Item] (find out how long DO is)
#
# ### [[ Slightly Updated Wording ]] Summarize your observation of the state elimination and which REs were introduced as a result (using the same guidelines as with Rev_RE1 above.
#
# * Going from `DO[0]` to `DO[1]`, the state `I3` got eliminated. The input RE was "" from state `Real_I`, and the outputs were "c" to state `F1` and "f" to state `B`. Thus, the elimation of `I3` introduced two new paths: `Real_I` goes to `F1` upon "c", and `Real_I` to `B` upon "f".
#
# * Going from `DO[3]` to `DO[4]`, the state `B` got eliminated. Since there was a self-loop on state `B` upon the symbol 's', when connecting the REs coming in and going out of `B`, "s\*" was added in between. The input REs were "(d+f)" and "f", both coming from state `Real_I`, and the outputs were "" to state `Real_F` and "b" to state `F2`. Thus, the elimation of `B` introduced four new paths: `Real_I` goes to `Real_F` upon "(((d + f)) (s)\*)" and "((f) (s)\*)" (combined into one, upon "(((d + f) + f) (s)\*)"), `Real_I` goes to to `F2` upon "((((d + f)) ((s)\* b)) + c)" and "(((f) ((s)\* b)) + c)" (combined into one, upon "((((d + f) + f) ((s)\* b)) + c)").

# %% [markdown]
# ## 3(d)i Check for isomorphism as requested between Rev_RE1 and Rev_RE2
#
# Apply a Jove call that is compact (and is in my lecture slides) that checks that Rev_RE1 and Rev_RE2
# are equivalent. It has to involve iso_dfa and min_dfa and other calls.

# %%
iso_dfa(min_dfa(nfa2dfa(re2nfa(Rev_RE1))), min_dfa(nfa2dfa(re2nfa(Rev_RE2))))
# Out:
# True

# %% [markdown]
# ## 3(d)i Check for isomorphism as requested between Rev_RE1 and Rev_RE1_hand
#
# Same methods as above.

# %%
# Just look at it again for comparison

Rev_RE1_hand
# Out:
# "c(''+a)+(d+f)s*(''+b+ba)"

# %%
iso_dfa(min_dfa(nfa2dfa(re2nfa(Rev_RE1))), min_dfa(nfa2dfa(re2nfa(Rev_RE1_hand))))
# Out:
# True

# %% [markdown]
# # Chasing down the RE2NFA components (SV)
#
# Find out where the s* components are and explain the set of all strings that precede s* in Rev_RE2 and the NFA of Rev_RE2
#
# Find out where the ending "a" is, and find out the set of all the symbols that precede a
#
# Let's first look at the NFA and then see where the RE "parts" are in it.

# %%
print(dotObj_nfa(re2nfa(Rev_RE2))) # for viewing it in a new tab
# Out:
# // NO_St38
# digraph {
# 	graph [rankdir=LR]
# 	EMPTY [label="" shape=plaintext]
# 	St1 [label=St1 peripheries=1 shape=circle]
# 	St21 [label=St21 peripheries=1 shape=circle]
# 	St3 [label=St3 peripheries=1 shape=circle]
# 	St26 [label=St26 peripheries=1 shape=circle]
# 	St16 [label=St16 peripheries=1 shape=circle]
# 	St29 [label=St29 peripheries=1 shape=circle]
# 	St34 [label=St34 peripheries=1 shape=circle]
# 	St30 [label=St30 peripheries=1 shape=circle]
# 	St27 [label=St27 peripheries=1 shape=circle]
# 	St23 [label=St23 peripheries=1 shape=circle]
# 	St7 [label=St7 peripheries=1 shape=circle]
# 	St9 [label=St9 peripheries=1 shape=circle]
# 	St25 [label=St25 peripheries=1 shape=circle]
# 	St13 [label=St13 peripheries=1 shape=circle]
# 	St10 [label=St10 peripheries=1 shape=circle]
# 	St6 [label=St6 peripheries=1 shape=circle]
# 	St12 [label=St12 peripheries=1 shape=circle]
# 	St2 [label=St2 peripheries=1 shape=circle]
# 	St33 [label=St33 peripheries=1 shape=circle]
# 	St31 [label=St31 peripheries=1 shape=circle]
# 	St5 [label=St5 peripheries=1 shape=circle]
# 	St4 [label=St4 peripheries=1 shape=circle]
# 	St36 [label=St36 peripheries=1 shape=circle]
# 	St35 [label=St35 peripheries=1 shape=circle]
# 	St11 [label=St11 peripheries=1 shape=circle]
# 	St15 [label=St15 peripheries=1 shape=circle]
# 	St32 [label=St32 peripheries=1 shape=circle]
# 	St22 [label=St22 peripheries=1 shape=circle]
# 	St20 [label=St20 peripheries=1 shape=circle]
# 	St14 [label=St14 peripheries=1 shape=circle]
# 	St8 [label=St8 peripheries=1 shape=circle]
# 	St24 [label=St24 peripheries=1 shape=circle]
# 	St19 [label=St19 peripheries=2 shape=circle]
# 	St37 [label=St37 peripheries=2 shape=circle]
# 	St18 [label=St18 peripheries=2 shape=circle]
# 	St28 [label=St28 peripheries=2 shape=circle]
# 	St17 [label=St17 peripheries=2 shape=circle]
# 	EMPTY -> St12
# 	EMPTY -> St33
# 	EMPTY -> St31
# 	EMPTY -> St1
# 	EMPTY -> St5
# 	EMPTY -> St22
# 	EMPTY -> St3
# 	EMPTY -> St20
# 	EMPTY -> St14
# 	EMPTY -> St29
# 	EMPTY -> St24
# 	St1 -> St2 [label="d "]
# 	St3 -> St4 [label="f "]
# 	St5 -> St6 [label="f "]
# 	St9 -> St10 [label="'' "]
# 	St9 -> St7 [label="'' "]
# 	St7 -> St8 [label="s "]
# 	St8 -> St9 [label="'' "]
# 	St10 -> St11 [label="b "]
# 	St6 -> St9 [label="'' "]
# 	St4 -> St9 [label="'' "]
# 	St2 -> St9 [label="'' "]
# 	St12 -> St13 [label="c "]
# 	St14 -> St15 [label="c "]
# 	St16 -> St17 [label="a "]
# 	St13 -> St16 [label="'' "]
# 	St13 -> St18 [label="'' "]
# 	St13 -> St19 [label="'' "]
# 	St11 -> St16 [label="'' "]
# 	St11 -> St18 [label="'' "]
# 	St11 -> St19 [label="'' "]
# 	St15 -> St16 [label="'' "]
# 	St15 -> St18 [label="'' "]
# 	St15 -> St19 [label="'' "]
# 	St20 -> St21 [label="d "]
# 	St22 -> St23 [label="f "]
# 	St24 -> St25 [label="f "]
# 	St28 -> St26 [label="'' "]
# 	St26 -> St27 [label="s "]
# 	St27 -> St28 [label="'' "]
# 	St25 -> St28 [label="'' "]
# 	St21 -> St28 [label="'' "]
# 	St23 -> St28 [label="'' "]
# 	St29 -> St30 [label="d "]
# 	St31 -> St32 [label="f "]
# 	St33 -> St34 [label="f "]
# 	St37 -> St35 [label="'' "]
# 	St35 -> St36 [label="s "]
# 	St36 -> St37 [label="'' "]
# 	St34 -> St37 [label="'' "]
# 	St30 -> St37 [label="'' "]
# 	St32 -> St37 [label="'' "]
# }

# %%
dotObj_nfa(re2nfa(Rev_RE2))

# %%
print(Rev_RE2)
# Out:
# ((((((((d + f) + f) ((s)* b)) + c) + c) ((a + "") + "")) + (((d + f) + f) (s)*)) + (((d + f) + f) (s)*))

# %% [markdown]
# ## Chasing down the RE2NFA components (SV) - details
#
#
# This is an exercise in explaning how Rev_RE2 got translated to an NFA. You are to pick these cases and find an example of each, and explain below. What you pick does not matter.
#
# * Find a case where a Star is used, and explain the construction, pointing to the states involved. Use up to 6 bullets below. More or less based on how you explain (clarity not length emphasized).
#   - There is an "s\*" occurred at the end of the regular expression.
#   - By inspecting the graph of the resulting NFA, I know that this operation contributed to making the states `St35`, `St36`, and `St37`.
#   - `St35` goes to `St36` upon the symbol 's', which corresponds to the "inside" of the star operation--the string "s".
#   - `St36` goes to `St37`, and `St37` goes to `St35`, both upon an epsilon, which correspond to the star operation itself: creating a new final state (`St37`) and connecting it to the original initial (`St35`) and final (`St36`) states of the "inside" of the star operation, both of which go upon an epsilon.
#
# * Find a case where the Star follows something (I.e. a concatenation of the form "X" followed by "Star" is used). Show how that concatenation construction is accomplished in the same manner (up to 6 bullets roughly) as above. More or less based on how you explain.
#   - There is a pattern "(d+f+f)s\*" occurred at the end of the regular expression, where the star operation "s\*" follows the expression "d+f+f".
#   - By inspecting the graph of the resulting NFA, I know that this portion of the expression contributed to making the states `St29` through `St37`.
#   - As explained before, the loop between states `St35`, `St36`, and `St37` corresponds to the expression "s\*".
#   - `St29` goes to `St30` upon the symbol 'd', `St31` goes to `St32` upon the symbol 'f', and `St33` goes to `St34` upon the symbol 'f', which correspond to the expression "d+f+f".
#   - `St30`, `St32`, and `St34` go to `St37` all upon an epsilon, where `St30`, `St32` and `St34` were originally the final states for the expression "d+f+f". This represents the string-concatenation operation between "d+f+f" and "s\*", and as a result, these three states lose their final status.
#
# * Find a case where something follows Star (I.e. a concatenation of the form "Star" followed by "X"). Explain how the concatenation is accomplished.
#   - There is a pattern "s\*b" occurred near the beginning of the regular expression, where the string "b" follows the string "s\*", a star operation.
#   - By inspecting the graph of the resulting NFA, I know that this portion of the expression contributed to making the states `St7` through `St11`.
#   - `St7` goes to `St8` upon the symbol 's', which corresponds to the "inside" of the star operation--the string "s".
#   - `St8` goes to `St9`, and `St9` goes to `St7`, both upon an epsilon, which correspond to the star operation itself: creating a new final state (`St9`) and connecting it to the original initial (`St7`) and final (`St8`) states of the "inside" of the star operation, both of which go upon an epsilon.
#   - `St10` goes to `St11` upon the symbol 'b', which corresponds to the string following "s\*".
#   - `St9` goes to `St10` upon an epsilon, representing the string-concatenation operation between "s\*" and "b". As a result, `St9` loses its final status.

# %% [markdown]
# ## Repeat finding out the aforesaid paths in your own Rev_RE1_hand

# %%
print(dotObj_nfa(re2nfa(Rev_RE1_hand))) # for viewing it in a new tab
print(Rev_RE1_hand)
# Out:
# // NO_St20
# digraph {
# 	graph [rankdir=LR]
# 	EMPTY [label="" shape=plaintext]
# 	St6 [label=St6 peripheries=1 shape=circle]
# 	St12 [label=St12 peripheries=1 shape=circle]
# 	St2 [label=St2 peripheries=1 shape=circle]
# 	St18 [label=St18 peripheries=1 shape=circle]
# 	St1 [label=St1 peripheries=1 shape=circle]
# 	St7 [label=St7 peripheries=1 shape=circle]
# 	St4 [label=St4 peripheries=1 shape=circle]
# 	St9 [label=St9 peripheries=1 shape=circle]
# 	St11 [label=St11 peripheries=1 shape=circle]
# 	St14 [label=St14 peripheries=1 shape=circle]
# 	St8 [label=St8 peripheries=1 shape=circle]
# 	St17 [label=St17 peripheries=1 shape=circle]
# 	St16 [label=St16 peripheries=1 shape=circle]
# 	St10 [label=St10 peripheries=1 shape=circle]
# 	St19 [label=St19 peripheries=2 shape=circle]
# 	St3 [label=St3 peripheries=2 shape=circle]
# 	St13 [label=St13 peripheries=2 shape=circle]
# 	St5 [label=St5 peripheries=2 shape=circle]
# 	St15 [label=St15 peripheries=2 shape=circle]
# 	EMPTY -> St6
# 	EMPTY -> St1
# 	EMPTY -> St8
# 	St1 -> St2 [label="c "]
# 	St4 -> St5 [label="a "]
# 	St2 -> St3 [label="'' "]
# 	St2 -> St4 [label="'' "]
# 	St6 -> St7 [label="d "]
# 	St8 -> St9 [label="f "]
# 	St12 -> St13 [label="'' "]
# 	St12 -> St10 [label="'' "]
# 	St12 -> St14 [label="'' "]
# 	St12 -> St16 [label="'' "]
# 	St10 -> St11 [label="s "]
# 	St11 -> St12 [label="'' "]
# 	St7 -> St12 [label="'' "]
# 	St9 -> St12 [label="'' "]
# 	St14 -> St15 [label="b "]
# 	St16 -> St17 [label="b "]
# 	St18 -> St19 [label="a "]
# 	St17 -> St18 [label="'' "]
# }
# c(''+a)+(d+f)s*(''+b+ba)

# %% [markdown]
# This is an exercise in explaning how Rev_RE1_hand got translated to an NFA. You are to pick these cases and find an example of each, and explain below. What you pick does not matter.
#
# * Find a case where a Star is used, and explain the construction, pointing to the states involved. Use up to 6 bullets below. More or less based on how you explain (clarity not length emphasized).
#   - There is an "s\*" occurred in the middle of the regular expression.
#   - By inspecting the graph of the resulting NFA, I know that this operation contributed to making the states `St10`, `St11`, and `St12`.
#   - `St10` goes to `St11` upon the symbol 's', which corresponds to the "inside" of the star operation--the string "s".
#   - `St11` goes to `St12`, and `St12` goes to `St10`, both upon an epsilon, which correspond to the star operation itself: creating a new final state (`St12`) and connecting it to the original initial (`St11`) and final (`St10`) states of the "inside" of the star operation, both of which go upon an epsilon.
#
# * Find a case where the Star follows something (I.e. a concatenation of the form "X" followed by "Star" is used). Show how that concatenation construction is accomplished in the same manner (up to 6 bullets roughly) as above. More or less based on how you explain.
#   - There is a pattern "(d+f)s\*" occurred in the middle of the regular expression, where the star operation "s\*" follows the expression "d+f".
#   - By inspecting the graph of the resulting NFA, I know that this portion of the expression contributed to making the states `St6` through `St12`.
#   - As explained before, the loop between states `St10`, `St11`, and `St12` corresponds to the expression "s\*".
#   - `St6` goes to `St7` upon the symbol 'd', and `St8` goes to `St9` upon the symbol 'f', which correspond to the expression "d+f".
#   - `St7` and `St9` go to `St12`, both upon an epsilon, where `St7` and `St9` were originally the final states for the expression "d+f". This represents the string-concatenation operation between "d+f" and "s\*", and as a result, both states lose their final status.
#
# * Find a case where something follows Star (I.e. a concatenation of the form "Star" followed by "X"). Explain how the concatenation is accomplished.
#   - There is a pattern "s\*(''+b+ba)" occurred at the end of the regular expression, where the expression "''+b+ba" follows the string "s\*", a star operation.
#   - By inspecting the graph of the resulting NFA, I know that this portion of the expression contributed to making the states `St10` through `St19`.
#   - As explained before, the loop between states `St10`, `St11`, and `St12` corresponds to the expression "s\*".
#   - Meanwhile, `St13` represents the epsilon part, `St14` and `St15` represent the "b" part, and `St16` through `St19` represent the "ba" part. The states `St13` through `St19` together represent the expression "''+b+ba".
#   - `St12` now goes to `St13`, `St14`, and `St16` upon an epsilon, where `St13`, `St14` and `St16` were originally the initial states for the expression "''+b+ba". This represents the string-concatenation operation between "s\*" and "''+b+ba". As a result, `St12` loses its final status.

# %% [markdown]
# # END
