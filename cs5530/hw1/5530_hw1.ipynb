# %% [markdown]
# $\text{}$
#
# $$\LARGE\text{Homework 1}$$
#
# $$\large\text{Qianlang Chen}$$
#
# $$\text{CS 5530 Spring 2022}$$
#
# $\text{}$

# %% [markdown]
# # Part 1
#
# ## Problem 1a
#
# $$\text{Cars}$$
# $$
# \begin{array}{|ccccc|}
#   \hline
#   \text{VIN} & \text{make} & \text{model} & \text{year} & \text{color}\\
#   \hline
#   0 & \texttt{"Toyota"} & \texttt{"Tacoma"} & 2008 & \texttt{"Red"}\\
#   1 & \texttt{"Toyota"} & \texttt{"Tacoma"} & 1999 & \texttt{"Green"}\\
#   2 & \texttt{"Tesla"} & \texttt{"Model 3"} & 2018 & \texttt{"White"}\\
#   3 & \texttt{"Subaru"} & \texttt{"WRX"} & 2016 & \texttt{"Blue"}\\
#   4 & \texttt{"Ford"} & \texttt{"F150"} & 2004 & \texttt{"Red"}\\
#   \hline
# \end{array}
# $$
#
# $$\text{Salespeople}$$
# $$
# \begin{array}{|cc|}
#   \hline
#   \text{SSN} & \text{name}\\
#   \hline
#   0 & \texttt{"Amold"}\\
#   1 & \texttt{"Jessica"}\\
#   2 & \texttt{"Steve"}\\
#   \hline
# \end{array}
# $$
#
# $\pagebreak$
#
# $$\text{Selling}$$
# $$
# \begin{array}{|cc|}
#   \hline
#   \text{SSN} & \text{VIN}\\
#   \hline
#   0 & 0\\
#   0 & 1\\
#   1 & 0\\
#   1 & 4\\
#   2 & 2\\
#   \hline
# \end{array}
# $$
#
# ## Problem 1b
#
# Each salesperson can only sell up to one car.
#
# ## Problem 1c
#
# Each car can only be dealt by at most one person.

# %% [markdown]
# $\pagebreak$
#
# # Part 2
#
# ## Problem 2
#
# $$
# \begin{array}{|lc|lc|}
#   \hline
#   \text{Attribute sets} & \text{Superkey} & \text{Proper subsets} & \text{Key}\\
#   \hline
#   \{\text{A1}\} & \text{no} & \{\} & \text{no}\\
#   \{\text{A2}\} & \text{no} & \{\} & \text{no}\\
#   \{\text{A3}\} & \text{no} & \{\} & \text{no}\\
#   \{\text{A1, A2}\} & \text{yes} & \{\text{A1}\}, \{\text{A2}\}, \{\} & \text{yes}\\
#   \{\text{A1, A3}\} & \text{no} & \{\text{A1}\}, \{\text{A3}\}, \{\} & \text{no}\\
#   \{\text{A2, A3}\} & \text{no} & \{\text{A2}\}, \{\text{A3}\}, \{\} & \text{no}\\
#   \{\text{A1, A2, A3}\} & \text{yes} & \{\text{A1, A2}\}, \{\text{A1, A3}\}, \{\text{A2, A3}\}, \{\text{A1}\}, \{\text{A2}\}, \{\text{A3}\}, \{\} & \text{no}\\
#   \hline
# \end{array}
# $$

# %% [markdown]
# $\pagebreak$
#
# # Part 3
#
# ## Problem 3a
#
# * PK{CardNum}
# * UQ{Serial}
#
# ## Problem 3b
#
# * PK{ISBN}
# * UQ{Title, Author}
#
# ## Problem 3c
#
# * PK{ISBN}
# * UQ{Title}
#
# ## Problem 3d
#
# * PK{Phone}

# %% [markdown]
# $\pagebreak$
#
# # Part 4
#
# ## Problem 4
#
# * `CheckedOut.CardNum` references `Patrons.CardNum`
# * `CheckedOut.Serial` references `Inventory.Serial`
# * `Patrons.CardNum` references `Patrons.CardNum`
# * `Titles.ISBN` references `Inventory.ISBN`

# %% [markdown]
# $\pagebreak$
#
# # Part 5
#
# ## Problem 5a
#
# True. If {$x$} is a superkey, all cells in column $x$ are unique, so all rows containing column $x$ are forced to be unique too.
#
# ## Problem 5b
#
# False. If {$x$} is a key, any set containing $x$ will have {$x$} as a proper subset, but that's already a superkey.
#
# ## Problem 5c
#
# True. Being a superkey is one condition of being a key.
#
# ## Problem 5d
#
# True. This is included in case 5a, where if {$x$} is a superkey, then {$x$, anything} is a superkey.
#
# ## Problem 5e
#
# False. As shown in 5d, If {$x$} is a superkey, then {$x, y$} is a superkey regardless of what is in column $y$ (where $y$ may contain duplicate cells).
#
# ## Problem 5f
#
# False. For example, if {$x, y, z$} was a key, none of its proper subsets could be a superkey.
#
# ## Problem 5g
#
# True. A valid relation must have unique rows, so in this case it is only possible that {$x, y, z$} is a key, since no other combination of attributes make a key to enforce that uniqueness.
#
# ## Problem 5h
#
# False. The following relation has one unique <$x, z$> pair (<0, 0>) but two unique $y$ values, 0 and 1:
# $$
# \begin{array}{|ccc|}
#   \hline
#   x & y & z\\
#   \hline
#   0 & 0 & 0\\
#   0 & 1 & 0\\
#   \hline
# \end{array}
# $$
